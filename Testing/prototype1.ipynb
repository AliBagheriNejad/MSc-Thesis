# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import shutil
from scipy import signal

# %matplotlib inline

# %%
# Changing working directory
os.chdir(r'G:\Masters\Thesis\Data\data')
# Get all files in the directory
current_path = os.getcwd()
file_names = os.listdir(current_path)

# Get .csv files
csv_files = []
for file in file_names:

    if '.csv' in file:
        csv_files.append(file)

# %% [markdown]
# Working with a csv file

# %%
# Reading files
dfs =[]
for file in csv_files:

    df = pd.read_csv(file)
    dfs.append(df)

# Combine all dataframes
test_df = pd.concat(dfs, axis=0, ignore_index=True)

print(f'There are total number of {test_df.shape[0]} rows')
test_df.head(10)
# Out:
# There are total number of 24 rows
#    Unnamed: 0        date      time                   kks  \
# 0           0  07/19/2023  14:30:00  32_COMP_RAW_PRO_XREL
# 1           1  07/21/2023  14:30:00  32_COMP_RAW_PRO_XREL
# 2           2  07/22/2023  14:30:02  32_COMP_RAW_PRO_XREL
# 3           0  07/19/2023  14:30:00  32_COMP_RAW_PRO_YREL
# 4           1  07/21/2023  14:30:00  32_COMP_RAW_PRO_YREL
# 5           2  07/22/2023  14:30:02  32_COMP_RAW_PRO_YREL
# 6           0  08/22/2023  14:30:01  32_COMP_RAW_PRO_YREL
# 7           0  08/22/2023  14:30:01  32_COMP_RAW_PRO_XREL
# 8           0  09/30/2023  14:30:00  32_COMP_RAW_PRO_XREL
# 9           1  10/01/2023  14:30:00  32_COMP_RAW_PRO_XREL
#
#                                                 data unit  duration       dt
# 0  [-8.713050842285156, -8.711616516113281, -8.71...   um         1  0.00004
# 1  [-8.726463317871094, -8.725486755371094, -8.72...   um         1  0.00004
# 2  [-8.762596130371094, -8.765960693359375, -8.76...   um         1  0.00004
# 3  [-8.357803344726562, -8.355949401855469, -8.35...   um         1  0.00004
# 4  [-8.337944030761719, -8.336860656738281, -8.33...   um         1  0.00004
# 5  [-8.330734252929688, -8.329658508300781, -8.32...   um         1  0.00004
# 6  [-8.446327209472656, -8.445404052734375, -8.44...   um         1  0.00004
# 7  [-8.672065734863281, -8.6728515625, -8.6717376...   um         1  0.00004
# 8  [-8.679725646972656, -8.679000854492188, -8.68...   um         1  0.00004
# 9  [-8.637619018554688, -8.636550903320312, -8.63...   um         1  0.00004

# %% [markdown]
# The Duration of data sample is 1 seconds
#
# sample rate is 25000 Hz
#
# NOTE: There is no horizontal data
#
# ---

# %% [markdown]
# More into data

# %%
name_in_kks = test_df.kks.unique()
print(f'Data types in the current dataset :\n{name_in_kks}')
# Out:
# Data types in the current dataset :
# ['32_COMP_RAW_PRO_XREL' '32_COMP_RAW_PRO_YREL' '32_TURB_RAW_PRO_XREL'
#  '32_TURB_RAW_PRO_YREL']

# %%
# print(f'For the file {test_file}:')

# Shape of data
print(f'The shape of the dateframe is {test_df.shape}')

# Extracting data feature
test_data = test_df.data[0]
print(f"Type of the data in DataFrame is {type(test_data)}")
test_data = np.array(eval(test_data))
print(f'data shape is {test_data.shape}', end='\n\n')
# Out:
# The shape of the dateframe is (24, 8)
# Type of the data in DataFrame is <class 'str'>
# data shape is (25000,)

# %%
# Extracting all data
all_data = np.zeros((test_df.shape[0],25000))

for i, data in enumerate(test_df.data):

    data = eval(data)
    data = np.array(data).reshape(-1,)
    data = signal.detrend(data) # Detrending the signal
    all_data[i,:] = data

# %% [markdown]
# Plot signals
#
# Trend of signals is eliminated

# %%
hight = test_df.shape[0]
H = hight * 3
plt.figure(figsize=(10,H))
x_axis = np.linspace(0,1,25000)

# Plotting signals
for i in range(hight):

    plt.subplot(hight, 1, i+1)
    plt.plot(x_axis, all_data[i,:])
    plt.xlabel('time [sec]')
    plt.title(test_df['kks'][i])
    plt.grid()
plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# FFT

# %%
def plot_freq (signal):
    lim = 500
    fft_test = np.fft.fft(signal)
    freqs = np.fft.fftfreq(len(fft_test)) * 25000
    plt.plot(np.abs(freqs)[:lim], np.abs(fft_test)[:lim])
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Amplitude')
    plt.grid(True)

# %%
hight = test_df.shape[0]
H = hight * 3
plt.figure(figsize=(10,H))

# Plotting signals
for i in range(hight):

    plt.subplot(hight, 1, i+1)
    plot_freq(all_data[i,:])
    plt.title(test_df['kks'][i])
plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# ## Hilbert-Huang

# %%
from pyhht.visualization import plot_imfs
from pyhht.emd import EMD
from scipy.signal import hilbert

signal = all_data[1,:]

# Perform empirical mode decomposition (EMD)
decomposer = EMD(signal)
imfs = decomposer.decompose()

# Apply Hilbert transform to each IMF
hilbert_imfs = []
for imf in imfs:
    hilbert_imfs.append(hilbert(imf))

# Plot the original signal, IMFs, and Hilbert transformed IMFs
plt.figure(figsize=(10, 15))
plt.subplot(len(hilbert_imfs) + 1, 1, 1)
plt.plot(x_axis, signal)
plt.title('Original Signal')

for i, hilbert_imf in enumerate(hilbert_imfs):
    plt.subplot(len(hilbert_imfs) + 1, 1, i + 2)
    plt.plot(x_axis, hilbert_imf.real, label='Hilbert Transformed')
    plt.plot(x_axis, imfs[i], '--', label='IMF')
    plt.legend()
    plt.title(f'IMF {i + 1}')

plt.tight_layout()
plt.show()

# %%
import emd

# %%
x = all_data[1,:]
imf = emd.sift.mask_sift(x, max_imfs=5)
IP, IF, IA = emd.spectra.frequency_transform(imf, 25000, 'nht')

# %%
# Carrier frequency histogram definition
freq_edges, freq_centres = emd.spectra.define_hist_bins(1, 25, 24*3, 'linear')

f, hht = emd.spectra.hilberthuang(IF[:, 2], IA[:, 2], freq_edges, mode='amplitude', sum_time=False)
time_centres = np.arange(201)-.5

# Create summary figure

plt.figure(figsize=(10, 6))
plt.plot(IF[:, 2], 'g', linewidth=3)
plt.legend(['IF'])

# Plot HHT
plt.pcolormesh(time_centres, freq_edges, hht[:, :200], cmap='hot_r', vmin=0)

# Set colourbar
cb = plt.colorbar()
cb.set_label('Amplitude', rotation=90)

# Add some grid lines
for ii in range(len(freq_edges)):
    plt.plot((0, 200), (freq_edges[ii], freq_edges[ii]), 'k', linewidth=.5)
for ii in range(200):
    plt.plot((ii, ii), (0, 20), 'k', linewidth=.5)

# Overlay the IF again for better visualisation
plt.plot(IF[:, 2], 'g', linewidth=3)

# Set lims and labels
plt.xlim(50, 1500)
plt.ylim(1800, 2000)
plt.xlabel('Time (samples)')
plt.ylabel('Frequency (Hz)')
# Out:
# Text(0, 0.5, 'Frequency (Hz)')

# %% [markdown]
# ## Orbit

# %% [markdown]
# Selecting data for a specific day

# %%
dates = test_df['date'].unique()
date_df = test_df[test_df.date==dates[2]]
date_df.head()
# Out:
#     Unnamed: 0        date      time                   kks  \
# 2            2  07/22/2023  14:30:02  32_COMP_RAW_PRO_XREL
# 5            2  07/22/2023  14:30:02  32_COMP_RAW_PRO_YREL
# 18           2  07/22/2023  14:30:02  32_TURB_RAW_PRO_XREL
# 21           2  07/22/2023  14:30:02  32_TURB_RAW_PRO_YREL
#
#                                                  data unit  duration       dt
# 2   [-8.762596130371094, -8.765960693359375, -8.76...   um         1  0.00004
# 5   [-8.330734252929688, -8.329658508300781, -8.32...   um         1  0.00004
# 18  [-8.635719299316406, -8.633552551269531, -8.63...   um         1  0.00004
# 21  [-8.340065002441406, -8.343544006347656, -8.34...   um         1  0.00004

# %% [markdown]
# Selecting turbine data

# %%
turb_df = date_df[['TURB' in name for name in date_df.kks.values]]
turb_df.head()
# Out:
#     Unnamed: 0        date      time                   kks  \
# 17           1  07/21/2023  14:30:00  32_TURB_RAW_PRO_XREL
# 20           1  07/21/2023  14:30:00  32_TURB_RAW_PRO_YREL
#
#                                                  data unit  duration       dt
# 17  [-8.565818786621094, -8.566604614257812, -8.56...   um         1  0.00004
# 20  [-8.25640869140625, -8.258338928222656, -8.260...   um         1  0.00004

# %%
xx = all_data[18][0:1000]
yy = all_data[21][0:1000]

# plt.scatter([xx[0]], [yy[0]],c='green', s=50, label='begining')
# plt.scatter([xx[-1]], [yy[-1]],c='red', s=50, label='ending')
plt.plot(xx,yy, label='path')

xx = all_data[17][0:1000]
yy = all_data[20][0:1000]
plt.plot(xx,yy, label='path')
